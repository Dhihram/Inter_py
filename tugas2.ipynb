# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = "/content/drive/MyDrive/intermediate_python/My Uber Drives - 2016.csv"

# %%
df = pd.read_csv(dataset)
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
index = ['Start Date', 'End Date', "Category", "Start City", "Stop City", "Miles", "Purpose"]
df.columns = index
df
# Out:
#             Start Date          End Date  Category        Start City  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#              Stop City    Miles          Purpose
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %% [markdown]
# Kategorisasi Cara I
# menggunakan numpy

# %%
 conditions = [
    ((df['Miles'] < 5)),
    ((df['Miles'] >= 5)& (df['Miles']<=10)),
    ((df['Miles'] > 10))
]
choices = ['Short trip','Medium trip','Long trip']

# %%
df['Miles_cat'] = np.select(conditions, choices, default='NA')
df
# Out:
#             Start Date          End Date  Category        Start City  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#              Stop City    Miles          Purpose    Miles_cat
# 0          Fort Pierce      5.1   Meal/Entertain  Medium trip
# ...

# %% [markdown]
# Kategorisasi Cara II Menggunakan Loc

# %%
def kat(df):
    df.loc[(df['Miles'] < 5),'Miles_cat'] = 'Short trip'
    df.loc[(df['Miles'] >= 5) & (df['Miles'] <= 10) ,'Miles_cat'] = 'Medium trip'
    df.loc[(df['Miles'] > 10),'Miles_cat'] = 'Long trip'
    df['Miles_cat'].fillna('C', inplace=True)

# %%
kat(df)
df
# Out:
#             Start Date          End Date  Category        Start City  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#              Stop City    Miles          Purpose    Miles_cat
# 0          Fort Pierce      5.1   Meal/Entertain  Medium trip
# ...

# %% [markdown]
# Kategorisasi Cara III Menggunakan If

# %%
def kat_fi(df):    
    if (df['Miles'] < 5):
        return 'Short trip'
    elif (df['Miles'] >= 5) & (df['Miles'] <= 10):
        return 'Medium trip'
    elif (df['Miles'] > 10):
        return "Long trip"

# %%
df['miles_cat'] = df.apply(kat_fi, axis = 1)

# %%
df
# Out:
#             Start Date          End Date  Category        Start City  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#              Stop City    Miles          Purpose    miles_cat
# 0          Fort Pierce      5.1   Meal/Entertain  Medium trip
# ...
