# %%
import numpy as np
from numpy import random

# %% [markdown]
# 1. Membuat matrix 4 x 4 dengan value dari 0-3

# %%
arr = random.randint(0,3, size=(4,4))
arr
# Out:
# array([[2, 0, 0, 2],
#        [1, 0, 2, 2],
#        [2, 1, 0, 2],
#        [0, 2, 1, 0]])

# %% [markdown]
# 2. Membuat array 4x4 dengan membuat dua array bersama dengan 2 axis

# %%
b = np.hsplit(arr,2)
b
# Out:
# [array([[2, 0],
#         [1, 0],
#         [2, 1],
#         [0, 2]]), array([[0, 2],
#         [2, 2],
#         [0, 2],
#         [1, 0]])]
